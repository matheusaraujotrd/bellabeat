# %% [markdown]
# # Bellabeat: estudo de caso

# %% [markdown]
# ## Sobre os dados:
#
# * Os dados utilizados são os dados do fitbit disponível em https://www.kaggle.com/datasets/arashnic/fitbit
#
# * O conjunto de dados possui os dados de cerca de 30 participantes que responderam uma pesquisa, consentindo com o compartilhamento dos dados de seus dispositivos Fitbit.
#
# * O tamanho da amostra dos dados é de apenas 33 participantes. É o suficiente para iniciarmos alguma análise, mas o ideal seria um maior número amostral. Utilizar os dados internos da Bellabeat teria ajudado muito nesse quesito.
#
# * Além desse conjunto de dados, também utilizarei algumas informações adicionais:
# *"Smartwatch unit shipment share worldwide in first quarter of 2021, by platform"*, por Counterpoint Research (via Statista)
# *"Quarterly smartwatch unit shipment share worldwide from 2018 to 2022, by vendor"*, por Counterpoint Research (via Statista)
#
# Esses dois conjuntos de dados já estão preparados na sua fonte, então não é preciso fazer nenhum tipo de tratamento.

# %% [markdown]
# ## Limpeza e Transformação dos Dados

# %%
# Se não possuir alguma das bibliotecas, basta instalá-la, removendo o asterisco (#) do código a ser executado.
# !pip install numpy
# !pip install pandas
# !pip install summarytools

# %%
import numpy as np
import pandas as pd
import summarytools as dfs

daily_activity = pd.read_csv(r"""C:\Users\mathe\Desktop\Power BI\Bellabeat (Google Analytics)\datasets\Fitabase Data 4.12.16-5.12.16\dailyActivity_merged.csv""", sep=",")

# %%
dfs.dfSummary(daily_activity)
# Out:
# <style type="text/css">
# #T_4e74f thead>tr>th {
#   text-align: left;
# }
# #T_4e74f_row0_col0, #T_4e74f_row1_col0, #T_4e74f_row2_col0, #T_4e74f_row3_col0, #T_4e74f_row4_col0, #T_4e74f_row5_col0, #T_4e74f_row6_col0, #T_4e74f_row7_col0, #T_4e74f_row8_col0, #T_4e74f_row9_col0, #T_4e74f_row10_col0, #T_4e74f_row11_col0, #T_4e74f_row12_col0, #T_4e74f_row13_col0, #T_4e74f_row14_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_4e74f_row0_col1, #T_4e74f_row1_col1, #T_4e74f_row2_col1, #T_4e74f_row3_col1, #T_4e74f_row4_col1, #T_4e74f_row5_col1, #T_4e74f_row6_col1, #T_4e74f_row7_col1, #T_4e74f_row8_col1, #T_4e74f_row9_col1, #T_4e74f_row10_col1, #T_4e74f_row11_col1, #T_4e74f_row12_col1, #T_4e74f_row13_col1, #T_4e74f_row14_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_4e74f_row0_col2, #T_4e74f_row1_col2, #T_4e74f_row2_col2, #T_4e74f_row3_col2, #T_4e74f_row4_col2, #T_4e74f_row5_col2, #T_4e74f_row6_col2, #T_4e74f_row7_col2, #T_4e74f_row8_col2, #T_4e74f_row9_col2, #T_4e74f_row10_col2, #T_4e74f_row11_col2, #T_4e74f_row12_col2, #T_4e74f_row13_col2, #T_4e74f_row14_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_4e74f_row0_col3, #T_4e74f_row1_col3, #T_4e74f_row2_col3, #T_4e74f_row3_col3, #T_4e74f_row4_col3, #T_4e74f_row5_col3, #T_4e74f_row6_col3, #T_4e74f_row7_col3, #T_4e74f_row8_col3, #T_4e74f_row9_col3, #T_4e74f_row10_col3, #T_4e74f_row11_col3, #T_4e74f_row12_col3, #T_4e74f_row13_col3, #T_4e74f_row14_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_4e74f_row0_col4, #T_4e74f_row1_col4, #T_4e74f_row2_col4, #T_4e74f_row3_col4, #T_4e74f_row4_col4, #T_4e74f_row5_col4, #T_4e74f_row6_col4, #T_4e74f_row7_col4, #T_4e74f_row8_col4, #T_4e74f_row9_col4, #T_4e74f_row10_col4, #T_4e74f_row11_col4, #T_4e74f_row12_col4, #T_4e74f_row13_col4, #T_4e74f_row14_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_4e74f_row0_col5, #T_4e74f_row1_col5, #T_4e74f_row2_col5, #T_4e74f_row3_col5, #T_4e74f_row4_col5, #T_4e74f_row5_col5, #T_4e74f_row6_col5, #T_4e74f_row7_col5, #T_4e74f_row8_col5, #T_4e74f_row9_col5, #T_4e74f_row10_col5, #T_4e74f_row11_col5, #T_4e74f_row12_col5, #T_4e74f_row13_col5, #T_4e74f_row14_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_4e74f">
#   <caption><strong>Data Frame Summary</strong><br>daily_activity<br>Dimensions: 940 x 15<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_4e74f_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_4e74f_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_4e74f_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_4e74f_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_4e74f_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_4e74f_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4e74f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4e74f_row0_col1" class="data row0 col1" ><strong>Id</strong><br>[int64]</td>
#       <td id="T_4e74f_row0_col2" class="data row0 col2" >Mean (sd) : 4855407369.3 (2424805475.7)<br>min < med < max:<br>1503960366.0 < 4445114986.0 < 8877689391.0<br>IQR (CV) : 4642054065.0 (2.0)</td>
#       <td id="T_4e74f_row0_col3" class="data row0 col3" >33 distinct values</td>
#       <td id="T_4e74f_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_4e74f_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_4e74f_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_4e74f_row1_col1" class="data row1 col1" ><strong>ActivityDate</strong><br>[object]</td>
#       <td id="T_4e74f_row1_col2" class="data row1 col2" >1. 4/12/2016<br>2. 4/14/2016<br>3. 4/15/2016<br>4. 4/13/2016<br>5. 4/23/2016<br>6. 4/29/2016<br>7. 4/28/2016<br>8. 4/26/2016<br>9. 4/25/2016<br>10. 4/24/2016<br>11. other</td>
#       <td id="T_4e74f_row1_col3" class="data row1 col3" >33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>616 (65.5%)</td>
#       <td id="T_4e74f_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_4e74f_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_4e74f_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_4e74f_row2_col1" class="data row2 col1" ><strong>TotalSteps</strong><br>[int64]</td>
#       <td id="T_4e74f_row2_col2" class="data row2 col2" >Mean (sd) : 7637.9 (5087.2)<br>min < med < max:<br>0.0 < 7405.5 < 36019.0<br>IQR (CV) : 6937.2 (1.5)</td>
#       <td id="T_4e74f_row2_col3" class="data row2 col3" >842 distinct values</td>
#       <td id="T_4e74f_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_4e74f_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_4e74f_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_4e74f_row3_col1" class="data row3 col1" ><strong>TotalDistance</strong><br>[float64]</td>
#       <td id="T_4e74f_row3_col2" class="data row3 col2" >Mean (sd) : 5.5 (3.9)<br>min < med < max:<br>0.0 < 5.2 < 28.0<br>IQR (CV) : 5.1 (1.4)</td>
#       <td id="T_4e74f_row3_col3" class="data row3 col3" >615 distinct values</td>
#       <td id="T_4e74f_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_4e74f_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_4e74f_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_4e74f_row4_col1" class="data row4 col1" ><strong>TrackerDistance</strong><br>[float64]</td>
#       <td id="T_4e74f_row4_col2" class="data row4 col2" >Mean (sd) : 5.5 (3.9)<br>min < med < max:<br>0.0 < 5.2 < 28.0<br>IQR (CV) : 5.1 (1.4)</td>
#       <td id="T_4e74f_row4_col3" class="data row4 col3" >613 distinct values</td>
#       <td id="T_4e74f_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_4e74f_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_4e74f_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_4e74f_row5_col1" class="data row5 col1" ><strong>LoggedActivitiesDistance</strong><br>[float64]</td>
#       <td id="T_4e74f_row5_col2" class="data row5 col2" >Mean (sd) : 0.1 (0.6)<br>min < med < max:<br>0.0 < 0.0 < 4.9<br>IQR (CV) : 0.0 (0.2)</td>
#       <td id="T_4e74f_row5_col3" class="data row5 col3" >19 distinct values</td>
#       <td id="T_4e74f_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_4e74f_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_4e74f_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_4e74f_row6_col1" class="data row6 col1" ><strong>VeryActiveDistance</strong><br>[float64]</td>
#       <td id="T_4e74f_row6_col2" class="data row6 col2" >Mean (sd) : 1.5 (2.7)<br>min < med < max:<br>0.0 < 0.2 < 21.9<br>IQR (CV) : 2.1 (0.6)</td>
#       <td id="T_4e74f_row6_col3" class="data row6 col3" >333 distinct values</td>
#       <td id="T_4e74f_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_4e74f_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_4e74f_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_4e74f_row7_col1" class="data row7 col1" ><strong>ModeratelyActiveDistance</strong><br>[float64]</td>
#       <td id="T_4e74f_row7_col2" class="data row7 col2" >Mean (sd) : 0.6 (0.9)<br>min < med < max:<br>0.0 < 0.2 < 6.5<br>IQR (CV) : 0.8 (0.6)</td>
#       <td id="T_4e74f_row7_col3" class="data row7 col3" >211 distinct

# %%
daily_calories = pd.read_csv(r"""C:\Users\mathe\Desktop\Power BI\Bellabeat (Google Analytics)\datasets\Fitabase Data 4.12.16-5.12.16\dailyCalories_merged.csv""")
dfs.dfSummary(daily_calories)
# Out:
# <style type="text/css">
# #T_81a19 thead>tr>th {
#   text-align: left;
# }
# #T_81a19_row0_col0, #T_81a19_row1_col0, #T_81a19_row2_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_81a19_row0_col1, #T_81a19_row1_col1, #T_81a19_row2_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_81a19_row0_col2, #T_81a19_row1_col2, #T_81a19_row2_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_81a19_row0_col3, #T_81a19_row1_col3, #T_81a19_row2_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_81a19_row0_col4, #T_81a19_row1_col4, #T_81a19_row2_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_81a19_row0_col5, #T_81a19_row1_col5, #T_81a19_row2_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_81a19">
#   <caption><strong>Data Frame Summary</strong><br>daily_calories<br>Dimensions: 940 x 3<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_81a19_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_81a19_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_81a19_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_81a19_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_81a19_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_81a19_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_81a19_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_81a19_row0_col1" class="data row0 col1" ><strong>Id</strong><br>[int64]</td>
#       <td id="T_81a19_row0_col2" class="data row0 col2" >Mean (sd) : 4855407369.3 (2424805475.7)<br>min < med < max:<br>1503960366.0 < 4445114986.0 < 8877689391.0<br>IQR (CV) : 4642054065.0 (2.0)</td>
#       <td id="T_81a19_row0_col3" class="data row0 col3" >33 distinct values</td>
#       <td id="T_81a19_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_81a19_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_81a19_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_81a19_row1_col1" class="data row1 col1" ><strong>ActivityDay</strong><br>[object]</td>
#       <td id="T_81a19_row1_col2" class="data row1 col2" >1. 4/12/2016<br>2. 4/14/2016<br>3. 4/15/2016<br>4. 4/13/2016<br>5. 4/23/2016<br>6. 4/29/2016<br>7. 4/28/2016<br>8. 4/26/2016<br>9. 4/25/2016<br>10. 4/24/2016<br>11. other</td>
#       <td id="T_81a19_row1_col3" class="data row1 col3" >33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>616 (65.5%)</td>
#       <td id="T_81a19_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_81a19_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_81a19_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_81a19_row2_col1" class="data row2 col1" ><strong>Calories</strong><br>[int64]</td>
#       <td id="T_81a19_row2_col2" class="data row2 col2" >Mean (sd) : 2303.6 (718.2)<br>min < med < max:<br>0.0 < 2134.0 < 4900.0<br>IQR (CV) : 964.8 (3.2)</td>
#       <td id="T_81a19_row2_col3" class="data row2 col3" >734 distinct values</td>
#       <td id="T_81a19_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_81a19_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
daily_intensities = pd.read_csv(r"""C:\Users\mathe\Desktop\Power BI\Bellabeat (Google Analytics)\datasets\Fitabase Data 4.12.16-5.12.16\dailyIntensities_merged.csv""")
dfs.dfSummary(daily_intensities)
# Out:
# <style type="text/css">
# #T_aea3b thead>tr>th {
#   text-align: left;
# }
# #T_aea3b_row0_col0, #T_aea3b_row1_col0, #T_aea3b_row2_col0, #T_aea3b_row3_col0, #T_aea3b_row4_col0, #T_aea3b_row5_col0, #T_aea3b_row6_col0, #T_aea3b_row7_col0, #T_aea3b_row8_col0, #T_aea3b_row9_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_aea3b_row0_col1, #T_aea3b_row1_col1, #T_aea3b_row2_col1, #T_aea3b_row3_col1, #T_aea3b_row4_col1, #T_aea3b_row5_col1, #T_aea3b_row6_col1, #T_aea3b_row7_col1, #T_aea3b_row8_col1, #T_aea3b_row9_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_aea3b_row0_col2, #T_aea3b_row1_col2, #T_aea3b_row2_col2, #T_aea3b_row3_col2, #T_aea3b_row4_col2, #T_aea3b_row5_col2, #T_aea3b_row6_col2, #T_aea3b_row7_col2, #T_aea3b_row8_col2, #T_aea3b_row9_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_aea3b_row0_col3, #T_aea3b_row1_col3, #T_aea3b_row2_col3, #T_aea3b_row3_col3, #T_aea3b_row4_col3, #T_aea3b_row5_col3, #T_aea3b_row6_col3, #T_aea3b_row7_col3, #T_aea3b_row8_col3, #T_aea3b_row9_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_aea3b_row0_col4, #T_aea3b_row1_col4, #T_aea3b_row2_col4, #T_aea3b_row3_col4, #T_aea3b_row4_col4, #T_aea3b_row5_col4, #T_aea3b_row6_col4, #T_aea3b_row7_col4, #T_aea3b_row8_col4, #T_aea3b_row9_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_aea3b_row0_col5, #T_aea3b_row1_col5, #T_aea3b_row2_col5, #T_aea3b_row3_col5, #T_aea3b_row4_col5, #T_aea3b_row5_col5, #T_aea3b_row6_col5, #T_aea3b_row7_col5, #T_aea3b_row8_col5, #T_aea3b_row9_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_aea3b">
#   <caption><strong>Data Frame Summary</strong><br>daily_intensities<br>Dimensions: 940 x 10<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_aea3b_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_aea3b_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_aea3b_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_aea3b_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_aea3b_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_aea3b_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aea3b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_aea3b_row0_col1" class="data row0 col1" ><strong>Id</strong><br>[int64]</td>
#       <td id="T_aea3b_row0_col2" class="data row0 col2" >Mean (sd) : 4855407369.3 (2424805475.7)<br>min < med < max:<br>1503960366.0 < 4445114986.0 < 8877689391.0<br>IQR (CV) : 4642054065.0 (2.0)</td>
#       <td id="T_aea3b_row0_col3" class="data row0 col3" >33 distinct values</td>
#       <td id="T_aea3b_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_aea3b_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aea3b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_aea3b_row1_col1" class="data row1 col1" ><strong>ActivityDay</strong><br>[object]</td>
#       <td id="T_aea3b_row1_col2" class="data row1 col2" >1. 4/12/2016<br>2. 4/14/2016<br>3. 4/15/2016<br>4. 4/13/2016<br>5. 4/23/2016<br>6. 4/29/2016<br>7. 4/28/2016<br>8. 4/26/2016<br>9. 4/25/2016<br>10. 4/24/2016<br>11. other</td>
#       <td id="T_aea3b_row1_col3" class="data row1 col3" >33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>616 (65.5%)</td>
#       <td id="T_aea3b_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_aea3b_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aea3b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_aea3b_row2_col1" class="data row2 col1" ><strong>SedentaryMinutes</strong><br>[int64]</td>
#       <td id="T_aea3b_row2_col2" class="data row2 col2" >Mean (sd) : 991.2 (301.3)<br>min < med < max:<br>0.0 < 1057.5 < 1440.0<br>IQR (CV) : 499.8 (3.3)</td>
#       <td id="T_aea3b_row2_col3" class="data row2 col3" >549 distinct values</td>
#       <td id="T_aea3b_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_aea3b_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aea3b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_aea3b_row3_col1" class="data row3 col1" ><strong>LightlyActiveMinutes</strong><br>[int64]</td>
#       <td id="T_aea3b_row3_col2" class="data row3 col2" >Mean (sd) : 192.8 (109.2)<br>min < med < max:<br>0.0 < 199.0 < 518.0<br>IQR (CV) : 137.0 (1.8)</td>
#       <td id="T_aea3b_row3_col3" class="data row3 col3" >335 distinct values</td>
#       <td id="T_aea3b_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_aea3b_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aea3b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_aea3b_row4_col1" class="data row4 col1" ><strong>FairlyActiveMinutes</strong><br>[int64]</td>
#       <td id="T_aea3b_row4_col2" class="data row4 col2" >Mean (sd) : 13.6 (20.0)<br>min < med < max:<br>0.0 < 6.0 < 143.0<br>IQR (CV) : 19.0 (0.7)</td>
#       <td id="T_aea3b_row4_col3" class="data row4 col3" >81 distinct values</td>
#       <td id="T_aea3b_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_aea3b_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aea3b_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_aea3b_row5_col1" class="data row5 col1" ><strong>VeryActiveMinutes</strong><br>[int64]</td>
#       <td id="T_aea3b_row5_col2" class="data row5 col2" >Mean (sd) : 21.2 (32.8)<br>min < med < max:<br>0.0 < 4.0 < 210.0<br>IQR (CV) : 32.0 (0.6)</td>
#       <td id="T_aea3b_row5_col3" class="data row5 col3" >122 distinct values</td>
#       <td id="T_aea3b_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_aea3b_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aea3b_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_aea3b_row6_col1" class="data row6 col1" ><strong>SedentaryActiveDistance</strong><br>[float64]</td>
#       <td id="T_aea3b_row6_col2" class="data row6 col2" >1. 0.0<br>2. 0.0099999997764825<br>3. 0.0199999995529652<br>4. 0.0299999993294477<br>5. 0.0500000007450581<br>6. 0.0700000002980232<br>7. 0.0399999991059303<br>8. 0.109999999403954<br>9. 0.100000001490116</td>
#       <td id="T_aea3b_row6_col3" class="data row6 col3" >858 (91.3%)<br>50 (5.3%)<br>21 (2.2%)<br>4 (0.4%)<br>3 (0.3%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)</td>
#       <td id="T_aea3b_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_aea3b_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aea3b_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_aea3b_row7_col1" class="data row7 col1" ><strong>LightActiveDistance</strong><br>[float64]</td>
#       <td id="T_aea3b_row7_col2" class="data row7 col2" >Mean (sd) : 3.3 (2.0)<br>min < med < max:<br>0.0 < 3.4 < 10.7<br>IQR (CV) : 2.8 (1.6)</td>
#       <td id="T_aea3b_row7_col3" class="data row7 col3" >491 distinct values</td>
#       <td id="T_aea3b_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_aea3b_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aea3b_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_aea3b_row8_col1" class="data row8 col1" ><strong>ModeratelyActiveDistance</strong><br>[float64]</td>
#       <td id="T_aea3b_ro

# %%
daily_steps = pd.read_csv(r"""C:\Users\mathe\Desktop\Power BI\Bellabeat (Google Analytics)\datasets\Fitabase Data 4.12.16-5.12.16\dailySteps_merged.csv""")
dfs.dfSummary(daily_steps)
# Out:
# <style type="text/css">
# #T_dfb31 thead>tr>th {
#   text-align: left;
# }
# #T_dfb31_row0_col0, #T_dfb31_row1_col0, #T_dfb31_row2_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_dfb31_row0_col1, #T_dfb31_row1_col1, #T_dfb31_row2_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_dfb31_row0_col2, #T_dfb31_row1_col2, #T_dfb31_row2_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_dfb31_row0_col3, #T_dfb31_row1_col3, #T_dfb31_row2_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_dfb31_row0_col4, #T_dfb31_row1_col4, #T_dfb31_row2_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_dfb31_row0_col5, #T_dfb31_row1_col5, #T_dfb31_row2_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_dfb31">
#   <caption><strong>Data Frame Summary</strong><br>daily_steps<br>Dimensions: 940 x 3<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_dfb31_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_dfb31_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_dfb31_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_dfb31_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_dfb31_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_dfb31_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dfb31_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_dfb31_row0_col1" class="data row0 col1" ><strong>Id</strong><br>[int64]</td>
#       <td id="T_dfb31_row0_col2" class="data row0 col2" >Mean (sd) : 4855407369.3 (2424805475.7)<br>min < med < max:<br>1503960366.0 < 4445114986.0 < 8877689391.0<br>IQR (CV) : 4642054065.0 (2.0)</td>
#       <td id="T_dfb31_row0_col3" class="data row0 col3" >33 distinct values</td>
#       <td id="T_dfb31_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_dfb31_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_dfb31_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_dfb31_row1_col1" class="data row1 col1" ><strong>ActivityDay</strong><br>[object]</td>
#       <td id="T_dfb31_row1_col2" class="data row1 col2" >1. 4/12/2016<br>2. 4/14/2016<br>3. 4/15/2016<br>4. 4/13/2016<br>5. 4/23/2016<br>6. 4/29/2016<br>7. 4/28/2016<br>8. 4/26/2016<br>9. 4/25/2016<br>10. 4/24/2016<br>11. other</td>
#       <td id="T_dfb31_row1_col3" class="data row1 col3" >33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>616 (65.5%)</td>
#       <td id="T_dfb31_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_dfb31_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_dfb31_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_dfb31_row2_col1" class="data row2 col1" ><strong>StepTotal</strong><br>[int64]</td>
#       <td id="T_dfb31_row2_col2" class="data row2 col2" >Mean (sd) : 7637.9 (5087.2)<br>min < med < max:<br>0.0 < 7405.5 < 36019.0<br>IQR (CV) : 6937.2 (1.5)</td>
#       <td id="T_dfb31_row2_col3" class="data row2 col3" >842 distinct values</td>
#       <td id="T_dfb31_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_dfb31_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
daily_sleep = pd.read_csv(r"""C:\Users\mathe\Desktop\Power BI\Bellabeat (Google Analytics)\datasets\Fitabase Data 4.12.16-5.12.16\sleepDay_merged.csv""")
dfs.dfSummary(daily_sleep)
# Out:
# <style type="text/css">
# #T_18566 thead>tr>th {
#   text-align: left;
# }
# #T_18566_row0_col0, #T_18566_row1_col0, #T_18566_row2_col0, #T_18566_row3_col0, #T_18566_row4_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_18566_row0_col1, #T_18566_row1_col1, #T_18566_row2_col1, #T_18566_row3_col1, #T_18566_row4_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_18566_row0_col2, #T_18566_row1_col2, #T_18566_row2_col2, #T_18566_row3_col2, #T_18566_row4_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_18566_row0_col3, #T_18566_row1_col3, #T_18566_row2_col3, #T_18566_row3_col3, #T_18566_row4_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_18566_row0_col4, #T_18566_row1_col4, #T_18566_row2_col4, #T_18566_row3_col4, #T_18566_row4_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_18566_row0_col5, #T_18566_row1_col5, #T_18566_row2_col5, #T_18566_row3_col5, #T_18566_row4_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_18566">
#   <caption><strong>Data Frame Summary</strong><br>daily_sleep<br>Dimensions: 413 x 5<br>Duplicates: 3</caption>
#   <thead>
#     <tr>
#       <th id="T_18566_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_18566_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_18566_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_18566_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_18566_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_18566_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_18566_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_18566_row0_col1" class="data row0 col1" ><strong>Id</strong><br>[int64]</td>
#       <td id="T_18566_row0_col2" class="data row0 col2" >Mean (sd) : 5000979403.2 (2060360173.7)<br>min < med < max:<br>1503960366.0 < 4702921684.0 < 8792009665.0<br>IQR (CV) : 2984847353.0 (2.4)</td>
#       <td id="T_18566_row0_col3" class="data row0 col3" >24 distinct values</td>
#       <td id="T_18566_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_18566_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_18566_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_18566_row1_col1" class="data row1 col1" ><strong>SleepDay</strong><br>[object]</td>
#       <td id="T_18566_row1_col2" class="data row1 col2" >1. 4/15/2016 12:00:00 AM<br>2. 5/1/2016 12:00:00 AM<br>3. 4/28/2016 12:00:00 AM<br>4. 4/30/2016 12:00:00 AM<br>5. 4/20/2016 12:00:00 AM<br>6. 4/21/2016 12:00:00 AM<br>7. 4/23/2016 12:00:00 AM<br>8. 4/29/2016 12:00:00 AM<br>9. 4/26/2016 12:00:00 AM<br>10. 5/8/2016 12:00:00 AM<br>11. other</td>
#       <td id="T_18566_row1_col3" class="data row1 col3" >17 (4.1%)<br>16 (3.9%)<br>16 (3.9%)<br>15 (3.6%)<br>15 (3.6%)<br>15 (3.6%)<br>15 (3.6%)<br>15 (3.6%)<br>14 (3.4%)<br>14 (3.4%)<br>261 (63.2%)</td>
#       <td id="T_18566_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_18566_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_18566_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_18566_row2_col1" class="data row2 col1" ><strong>TotalSleepRecords</strong><br>[int64]</td>
#       <td id="T_18566_row2_col2" class="data row2 col2" >Mean (sd) : 1.1 (0.3)<br>min < med < max:<br>1.0 < 1.0 < 3.0<br>IQR (CV) : 0.0 (3.2)</td>
#       <td id="T_18566_row2_col3" class="data row2 col3" >3 distinct values</td>
#       <td id="T_18566_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_18566_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_18566_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_18566_row3_col1" class="data row3 col1" ><strong>TotalMinutesAsleep</strong><br>[int64]</td>
#       <td id="T_18566_row3_col2" class="data row3 col2" >Mean (sd) : 419.5 (118.3)<br>min < med < max:<br>58.0 < 433.0 < 796.0<br>IQR (CV) : 129.0 (3.5)</td>
#       <td id="T_18566_row3_col3" class="data row3 col3" >256 distinct values</td>
#       <td id="T_18566_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_18566_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_18566_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_18566_row4_col1" class="data row4 col1" ><strong>TotalTimeInBed</strong><br>[int64]</td>
#       <td id="T_18566_row4_col2" class="data row4 col2" >Mean (sd) : 458.6 (127.1)<br>min < med < max:<br>61.0 < 463.0 < 961.0<br>IQR (CV) : 123.0 (3.6)</td>
#       <td id="T_18566_row4_col3" class="data row4 col3" >242 distinct values</td>
#       <td id="T_18566_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_18566_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Convertendo datas

daily_intensities["ActivityDay"] = pd.to_datetime(daily_intensities["ActivityDay"]).dt.date
daily_activity["ActivityDate"] = pd.to_datetime(daily_activity["ActivityDate"]).dt.date
daily_calories["ActivityDay"] = pd.to_datetime(daily_calories["ActivityDay"]).dt.date
daily_steps["ActivityDay"] = pd.to_datetime(daily_steps["ActivityDay"]).dt.date
daily_sleep["SleepDay"] = pd.to_datetime(daily_sleep["SleepDay"]).dt.date

# %%
dfs.dfSummary(daily_steps)
# Out:
# <style type="text/css">
# #T_cc821 thead>tr>th {
#   text-align: left;
# }
# #T_cc821_row0_col0, #T_cc821_row1_col0, #T_cc821_row2_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_cc821_row0_col1, #T_cc821_row1_col1, #T_cc821_row2_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_cc821_row0_col2, #T_cc821_row1_col2, #T_cc821_row2_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_cc821_row0_col3, #T_cc821_row1_col3, #T_cc821_row2_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_cc821_row0_col4, #T_cc821_row1_col4, #T_cc821_row2_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_cc821_row0_col5, #T_cc821_row1_col5, #T_cc821_row2_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_cc821">
#   <caption><strong>Data Frame Summary</strong><br>daily_steps<br>Dimensions: 940 x 3<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_cc821_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_cc821_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_cc821_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_cc821_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_cc821_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_cc821_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cc821_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_cc821_row0_col1" class="data row0 col1" ><strong>Id</strong><br>[int64]</td>
#       <td id="T_cc821_row0_col2" class="data row0 col2" >Mean (sd) : 4855407369.3 (2424805475.7)<br>min < med < max:<br>1503960366.0 < 4445114986.0 < 8877689391.0<br>IQR (CV) : 4642054065.0 (2.0)</td>
#       <td id="T_cc821_row0_col3" class="data row0 col3" >33 distinct values</td>
#       <td id="T_cc821_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_cc821_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_cc821_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_cc821_row1_col1" class="data row1 col1" ><strong>ActivityDay</strong><br>[object]</td>
#       <td id="T_cc821_row1_col2" class="data row1 col2" >1. 2016-04-12<br>2. 2016-04-14<br>3. 2016-04-15<br>4. 2016-04-13<br>5. 2016-04-23<br>6. 2016-04-29<br>7. 2016-04-28<br>8. 2016-04-26<br>9. 2016-04-25<br>10. 2016-04-24<br>11. other</td>
#       <td id="T_cc821_row1_col3" class="data row1 col3" >33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>33 (3.5%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>32 (3.4%)<br>616 (65.5%)</td>
#       <td id="T_cc821_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_cc821_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_cc821_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_cc821_row2_col1" class="data row2 col1" ><strong>StepTotal</strong><br>[int64]</td>
#       <td id="T_cc821_row2_col2" class="data row2 col2" >Mean (sd) : 7637.9 (5087.2)<br>min < med < max:<br>0.0 < 7405.5 < 36019.0<br>IQR (CV) : 6937.2 (1.5)</td>
#       <td id="T_cc821_row2_col3" class="data row2 col3" >842 distinct values</td>
#       <td id="T_cc821_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_cc821_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
daily_intensities.to_csv("CLEAN_daily_intensities.csv")
daily_activity.to_csv("CLEAN_daily_activity")
daily_calories.to_csv("CLEAN_daily_calories")
daily_steps.to_csv("CLEAN_daily_steps")
daily_sleep.to_csv("CLEAN_daily_sleep")
